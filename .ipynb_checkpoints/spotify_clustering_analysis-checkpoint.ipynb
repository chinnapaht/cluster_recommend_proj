# %%
from spot_clean import clean
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
import altair as alt

# %%
df = pd.read_excel("Spotify.xlsx")
df = clean(df)
df.drop(["title","artist","add_month","add_year"],axis = 1 , inplace = True)
df
# Out:
#                  genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 22      thai indie pop  2020  108    47    73  -8    17   25  292     56
# 24      thai indie pop  2013   97    49    70 -10    15   63  258     30
# 28           thai idol  2020  108    61    84  -6    11   78  244     33
# 34           thai folk  2019   99    17    48 -18    13   20  320     91
# 38     thai indie rock  2015  103    53    56 -10     5   45  223      0
# ...                ...   ...  ...   ...   ...  ..   ...  ...  ...    ...
# 2073           Unknown  2014  112    60    82  -7    10   93  221     82
# 2075  classic thai pop  2006   75    38    46 -10    28   33  234     61
# 2076      thai hip hop  2017  152    68    76  -7    14   43  194     53
# 2077      thai hip hop  2018  118    59    85  -4    18   68  189     81
# 2078      thai hip hop  2018   80    44    66  -6    13   51  192     88
#
#       spch  pop
# 22       3   61
# 24       3   60
# 28       3   60
# 34       4   56
# ...

# %%
cat_attribs = list(df.iloc[:,0:2])
num_attribs = list(df.iloc[:,3:])

full_pipeline = ColumnTransformer([
    ("num" , StandardScaler(),num_attribs),
    ("cat" , OneHotEncoder(),cat_attribs)
])

# %%
df_clus = full_pipeline.fit_transform(df)

# %% [markdown]
# Feature Enginering

# %%
df_encoded = pd.get_dummies(df,prefix=["encode"],columns=["year"])
df_encoded = pd.get_dummies(df,prefix=["encode"],columns=["genre"])
df_encoded
# Out:
#       year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  ...  \
# 22    2020  108    47    73  -8    17   25  292     56     3  ...
# 24    2013   97    49    70 -10    15   63  258     30     3  ...
# 28    2020  108    61    84  -6    11   78  244     33     3  ...
# 34    2019   99    17    48 -18    13   20  320     91     4  ...
# 38    2015  103    53    56 -10     5   45  223      0     3  ...
# ...    ...  ...   ...   ...  ..   ...  ...  ...    ...   ...  ...
# 2073  2014  112    60    82  -7    10   93  221     82     3  ...
# 2075  2006   75    38    46 -10    28   33  234     61     3  ...
# 2076  2017  152    68    76  -7    14   43  194     53    16  ...
# 2077  2018  118    59    85  -4    18   68  189     81     5  ...
# 2078  2018   80    44    66  -6    13   51  192     88     3  ...
#
#       encode_thai hip hop  encode_thai idol  encode_thai indie  \
# 22                      0                 0                  0
# ...

# %%
df_prin = df.copy()
cat_names = ['bpm','nrgy','dnce','dB','live','val','dur','acous','spch','pop']
features = df_prin[cat_names]
df_prin[cat_names] = scaler.fit_transform(features.values)

# %%
df_encoded = pd.get_dummies(df_prin,prefix=["encode"],columns=["year"])
df_encoded = pd.get_dummies(df_encoded,prefix=["encode"],columns=["genre"])

# %%
df_encoded
# Out:
#            bpm      nrgy      dnce        dB      live       val       dur  \
# 22   -0.602906 -0.669834  1.014435 -0.288147  0.132909 -1.096419  1.273628
# 24   -0.957477 -0.547819  0.759263 -1.067411 -0.075519  0.741293  0.290355
# 28   -0.602906  0.184271  1.950063  0.491118 -0.492374  1.466706 -0.114522
# 34   -0.893010 -2.500060 -1.111993 -4.184468 -0.283946 -1.338223  2.083383
# 38   -0.764075 -0.303789 -0.431536 -1.067411 -1.117656 -0.129202 -0.721838
# ...        ...       ...       ...       ...       ...       ...       ...
# 2073 -0.473971  0.123264  1.779949  0.101486 -0.596587  2.192118 -0.779678
# 2075 -1.666620 -1.218902 -1.282107 -1.067411  1.279260 -0.709532 -0.403720
# 2076  0.815379  0.611324  1.269606  0.101486 -0.179732 -0.225924 -1.560513
# 2077 -0.280569  0.062256  2.035120  1.270382  0.237123  0.983097 -1.705112
# 2078 -1.505451 -0.852857  0.419035  0.491118 -0.283946  0.160963 -1.618352
#
#          acous      spch       pop  ...  encode_thai hip hop  \
# ...

# %%
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(df_encoded) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
  
X_principal.head()
# Out:
#          P1        P2
# 0 -4.471229  1.334763
# 1 -3.656924  0.517675
# 2 -3.832017 -0.998076
# 3  0.614562  5.176564
# 4 -3.446515  0.284307

# %%
distortions = []
K = range(1, 30)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X_principal)
    distortions.append(kmeanModel.inertia_)
    
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('No of clusters (k)')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
distortions = []
K = range(1, 30)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df_clus)
    distortions.append(kmeanModel.inertia_)
    
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('No of clusters (k)')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=10)
kmeans.fit(df_clus)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df["cluster"] =  kmeans.labels_
df
# Out:
#                  genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 22      thai indie pop  2020  108    47    73  -8    17   25  292     56
# 24      thai indie pop  2013   97    49    70 -10    15   63  258     30
# 28           thai idol  2020  108    61    84  -6    11   78  244     33
# 34           thai folk  2019   99    17    48 -18    13   20  320     91
# 38     thai indie rock  2015  103    53    56 -10     5   45  223      0
# ...                ...   ...  ...   ...   ...  ..   ...  ...  ...    ...
# 2073           Unknown  2014  112    60    82  -7    10   93  221     82
# 2075  classic thai pop  2006   75    38    46 -10    28   33  234     61
# 2076      thai hip hop  2017  152    68    76  -7    14   43  194     53
# 2077      thai hip hop  2018  118    59    85  -4    18   68  189     81
# 2078      thai hip hop  2018   80    44    66  -6    13   51  192     88
#
#       spch  pop  cluster
# 22       3   61        0
# 24       3   60        1
# ...

# %%
alt.Chart(df).mark_circle(size=60).encode(
    x='bpm',
    y='acous',
    color='cluster',
    tooltip=['genre', 'year', 'pop']
).interactive()
# Out:
# alt.Chart(...)
